# %%
import pandas as pd
import matplotlib.pyplot as plt

from preprocessing import one_hot_encode_columns

# %%
data_file = "data/hour.csv"
df = pd.read_csv(data_file)
df.head(3)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32

# %%
cols = ["temp", "atemp", "hum", "windspeed"]
fig, ax = plt.subplots(len(cols), 1, figsize=(5, 25))

for i, col in enumerate(cols):
    ax[i].scatter(df[col], df["cnt"], alpha=0.2)
    ax[i].set_title(f"{col} vs count")

# %%
count = df["cnt"]
fig, ax = plt.subplots()

day_n = count[:-1]
day_n_plus_1 = count[1:]

ax.plot(range(len(count)), count)
